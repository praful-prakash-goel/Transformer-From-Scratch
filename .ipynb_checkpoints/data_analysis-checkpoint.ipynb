# %%
import pandas as pd

# %%
context_length = 32
pad_token = -1

# %%
df = pd.read_csv('eng_to_french.zip')
df = df[df['English words/sentences'].str.len() <= context_length]

print(df.shape)

df.head()
# Out:
# (113105, 2)
#   English words/sentences French words/sentences
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !

# %%
eng_text = df['English words/sentences'].tolist()
french_text = df['French words/sentences'].tolist()

# %%
eng_chars = set()

for sent in eng_text:
    for ch in sent:
# Out:
# ['3 to the third power is 27.', '5 is less than 8.', 'A baby has delicate skin.', 'A bad habit is easily acquired.', 'A bad smell permeated the room.', 'A ball hit her right leg.', 'A bear can climb a tree.', 'A beautiful girl sat next to me.', "A beautiful sunset, isn't it?", 'A bee flew out of the window.', 'A bee sting can be very painful.', 'A beer, please.', 'A big typhoon is approaching.', 'A billion adults are illiterate.', 'A bird has wings.', 'A black and white dog bit me.', 'A boat capsized.', 'A book is lying on the desk.', 'A bow is no use without arrows.', 'A boy came running toward me.', 'A boy came running towards me.', 'A bright idea occurred to me.', 'A broken mirror brings bad luck.', 'A burglar broke into his house.', 'A burnt child dreads fire.', 'A burnt child dreads the fire.', 'A button came off my coat.', 'A cab is waiting.', 'A car cut in.', 'A car drew up at the main gate.', 'A car has one steering wheel.', 'A car hit Tom.', 'A car went by at terrific speed.', 'A car went by.', 'A card was attached to the gift.', 'A cat can see in the dark.', 'A cat has nine lives.', 'A cat has two ears.', 'A cat is meowing on the roof.', 'A cat ran across the street.', 'A cat scratched me.', 'A catastrophe has been averted.', 'A century is one hundred years.', 'A child is crying somewhere.', 'A child is missing.', 'A child needs a mother.', 'A child needs love.', 'A child today would not do that.', 'A coke, please.', 'A cold front swept over Europe.', 'A cold spell gripped Europe.', 'A cold wind was blowing.', 'A compromise was reached.', 'A computer is a complex machine.', 'A cookie is under the table.', 'A cop was killed.', 'A crow is as black as coal.', 'A crowd gathered around.', 'A crowd gathered at the scene.', 'A cry arose from the crowd.', 'A cup of coffee, please.', 'A cup of tea, please.', 'A dairy cow is a useful animal.', 'A dance will be held on Friday.', 'A day has twenty-four hours.', 'A dead leaf fell to the ground.', 'A deal is a deal.', 'A decision had to be made.', 'A doctor was sent for at once.', 'A dog bit her leg.', 'A dog bit her on the leg.', 'A dog bit me this morning.', 'A dog can see in the dark.', 'A dog followed me to my house.', 'A dog followed me to my school.', 'A dog has four legs.', "A dog is a man's best friend.", 'A dog is barking.', 'A dog is following us.', 'A dog suddenly jumped at me.', 'A dog was following Tom.', 'A dog was run over by a truck.', 'A dog was running.', 'A dog will bark at strangers.', 'A dolphin is a kind of mammal.', 'A dolphin is a mammal.', 'A dove is a symbol of peace.', 'A drunk robbed me.', 'A dust storm is coming.', 'A face appeared at the window.', 'A fallen tree blocked the path.', 'A few days later, he came.', 'A few minutes is all I ask.', 'A few of these are mine.', 'A few serious problems remain.', 'A fierce battle was fought here.', 'A fire broke out last night.', 'A fire broke out near my house.', 'A fire broke out nearby.', 'A fish can swim.', 'A fish leaped out of the water.', 'A fish swims by moving its tail.', 'A fork fell off the table.', 'A fox is a wild animal.', 'A friend told me that story.', 'A frog came out of the water.', 'A full moon can be seen tonight.', 'A fuse has blown.', 'A gentle wind is blowing.', 'A girl appeared before me.', 'A girl can dream, right?', 'A girl phoned me.', 'A girl stood there crying.', 'A glass of water, please.', 'A good appetite is a good sauce.', 'A good citizen obeys the laws.', 'A good idea came across my mind.', 'A good idea came into my head.', 'A good idea came into my mind.', 'A good idea came to him.', 'A good idea occurred to him.', 'A good idea suddenly struck her.', 'A good many people were there.', 'A good medicine tastes bitter.', 'A good memory is his weapon.', 'A good sweat will cure a cold.', 'A great future lies before her.', 'A guard is outside.', "A guard's been killed.", 'A gun might come in handy.', 'A guy nearly ran into us.', 'A haiku is one type of poem.', 'A heavy frost is expect ...
# 75868
